# %%
import pandas as pd

# %%
df =pd.read_csv("Wine_Quality_Data.csv")
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
sns.distplot(df["fixed_acidity"])
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_14033/3808938824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["fixed_acidity"])
# <Axes: xlabel='fixed_acidity', ylabel='Density'>

# %%
df["fixed_acidity"].mean(),df["fixed_acidity"].median
# Out:
# (7.215307064799139,
#  <bound method Series.median of 0        7.4
#  1        7.8
#  2        7.8
#  3       11.2
#  4        7.4
#          ...
#  6492     6.2
#  6493     6.6
#  6494     6.5
#  6495     5.5
#  6496     6.0
#  Name: fixed_acidity, Length: 6497, dtype: float64>)

# %%
df1 = pd.read_csv("california_housing_train.csv")

# %%
sns.distplot(df1["median_house_value"])
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/255739491.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["median_house_value"])
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %%
sns.distplot(df1["median_house_value"], fit = norm)
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/1615546308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["median_house_value"], fit = norm)
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %%
# for positive skewness log can be used to convert that skewness to symmetrical data

# %%
df1["median_house_value_new"] = np.log(df1["median_house_value"])

# %%
sns.distplot(df1["median_house_value_new"], fit = norm)
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/411232311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["median_house_value_new"], fit = norm)
# <Axes: xlabel='median_house_value_new', ylabel='Density'>

# %%
df1["median_house_value"].skew()
# Out:
# 0.9730366334725522

# %%
df1["median_house_value_new"].skew() #skew value should be near to zero
# Out:
# -0.17859931565505424

# %%
#if the skewness is between -1 to -0.3 or 0.3 to 1 then data is considered as skewness. 
# in some rare case then the data is greater than 1 or lesser than -1 then the data is heavily skewed.

# %%
for i in df1.columns:
    print (i, df1[i].skew())
# Out:
# longitude -0.30400297675663496
# latitude 0.4718011203585246
# housing_median_age 0.06489403293452067
# total_rooms 4.002729998658741
# total_bedrooms 3.3226367155099132
# population 5.187211878247974
# households 3.3426683625335154
# median_income 1.6266930979614043
# median_house_value 0.9730366334725522
# median_house_value_new -0.17859931565505424

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
sns.distplot(df1["population"], fit = norm)
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/2230773285.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["population"], fit = norm)
# <Axes: xlabel='population', ylabel='Density'>

# %%
for i in df.columns:
    print (i, df[i].skew())
# Out:
# fixed_acidity 1.7232896467669239
# volatile_acidity 1.4950965423685545
# citric_acid 0.4717306724886708
# residual_sugar 1.4354042627889907
# chlorides 5.3998277319699035
# free_sulfur_dioxide 1.2200660740665203
# total_sulfur_dioxide -0.0011774782344379131
# density 0.5036017301419995
# pH 0.38683879806082694
# sulphates 1.7972700037785152
# alcohol 0.565717729098518
# quality 0.18962269337269683
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
# ...

# %%
sns.distplot(df["chlorides"], fit = norm)
# Out:
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/3279419543.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["chlorides"], fit = norm)
# <Axes: xlabel='chlorides', ylabel='Density'>

# %%
df1["median_house_value_new"] = np.log(df1["median_house_value"])

# %%
sns.distplot(df["chlorides"], fit = norm)

# %%
for i in df.columns[:-1]:
    print (i, df[i].skew())
    sns.distplot(df[i], fit = norm)
    plt.show()
# Out:
# fixed_acidity 1.7232896467669239
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/1778758906.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i], fit = norm)
# volatile_acidity 1.4950965423685545
# /var/folders/s3/w_ry2nkj7yg8gd7c39mx7xy00000gn/T/ipykernel_5458/1778758906.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
from scipy import stats

# %%
df1["median_house_value_new1"] = stats.boxcox(df1["median_house_value"],lmbda = 0)

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
methods = [0,0.5,-0.5,2,-2,-1]
for i in methods:
  print(pd.DataFrame(stats.boxcox(df1["population"],lmbda=i)).skew())
# Out:
# 0   -0.998581
# dtype: float64
# 0    1.27594
# dtype: float64
# 0   -7.67206
# dtype: float64
# 0    56.191377
# dtype: float64
# 0   -107.146618
# dtype: float64
# 0   -35.737806
# dtype: float64

# %%
for j in df1.columns:
    print(j, "\n")
    for i in methods:
        print(pd.DataFrame(stats.boxcox(df1[j],lmbda=i)).skew())
# Out:
# longitude
#
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# 0   NaN
# dtype: float64
# latitude
#
# 0    0.415517
# dtype: float64
# 0    0.443194
# dtype: float64
# 0    0.38867
# dtype: float64
# 0    0.53224
# dtype: float64
# 0    0.31214
# dtype: float64
# 0    0.362553
# dtype: float64
# housing_median_age
#
# 0   -1.272099
# dtype: float64
# 0   -0.465778
# dtype: float64
# 0   -2.672437
# dtype: float64
# 0    0.795659
# dtype: float64
# 0   -21.699554
# dtype: float64
# 0   -5.373318
# dtype: float64
# total_rooms
#
# 0   -1.025474
# dtype: float64
# 0    1.363921
# dtype: float64
# 0   -12.02768
# dtype: float64
# 0    15.115083
# dtype: float64
# 0   -128.957316
# dtype: float64
# 0   -83.158083
# dtype: float64
# total_bedrooms
#
# 0   -0.999423
# dtype: float64
# 0    1.206567
# dtype: float64
# 0   -8.616671
# dtype: float64
# 0    11.405313
# dtype: float64
# 0   -108.053231
# ...

# %% [markdown]
# # 1st august

# %%
df = pd.read_csv("Student_performance_data _.csv")

# %%
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.set_index('StudentID')
# Out:
#            Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# StudentID
# 1001        17       1          0                  2        19.833723
# 1002        18       0          0                  1        15.408756
# 1003        15       0          2                  3         4.210570
# 1004        17       1          0                  3        10.028829
# 1005        17       1          0                  2         4.672495
# ...        ...     ...        ...                ...              ...
# 3388        18       1          0                  3        10.680555
# 3389        17       0          0                  1         7.583217
# 3390        16       1          0                  2         6.805500
# 3391        16       1          1                  0        12.416653
# 3392        16       1          0                  2        17.819907
#
#            Absences  Tutoring  ParentalSupport  Extracurricular  Sports  \
# StudentID
# ...

# %%
df['StudyTimeWeekly'].skew()
# Out:
# 0.050068072558354076

# %%
import plotly.express as px

# %%
px.box(df, y = "GPA" , points = "all")
